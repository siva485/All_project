# %%
import pandas as pd

# %%
df = pd.read_excel('./Input/ME_Analysis.xlsx',sheet_name='Sheet1')

# %%
df.head()
# Out:
#    CalendarMonthStart Editorial Language  Issues EditorialCountryName  \
# 0            20160101            (blank)       1            Australia
# 1            20160101            (blank)      59                China
# 2            20160101            (blank)       5                China
# 3            20160101            (blank)       1                China
# 4            20160101            (blank)       1               France
#
#       ComponentName QueueCategory QueueCategory1 QueueCategory2  \
# 0           Appeals           NQP             AQ            NaN
# 1           Appeals           NQP             AQ            NaN
# 2        Complaints           NQP             AQ            NaN
# 3  Policy Questions           NQP             AQ            NaN
# 4           Appeals           NQP             AQ            NaN
#
#        Country&Lang Country&Lang(T/F) Only Country Only Lang
# 0  Australia(blank)               NaN          NaN       NaN
# ...

# %%
g = df.groupby(['CalendarMonthStart'])['Issues']

# %%
def convert_dt_int_to_dt(dt_int_):
    return datetime.strptime(str(dt_int_),'%Y%m%d')

# %%
df.CalendarMonthStart.map()
# Out:
#        CalendarMonthStart Editorial Language  Issues EditorialCountryName  \
# 0                20160101            (blank)       1            Australia
# 1                20160101            (blank)      59                China
# 2                20160101            (blank)       5                China
# 3                20160101            (blank)       1                China
# 4                20160101            (blank)       1               France
# ...                   ...                ...     ...                  ...
# 29877            20210601           Croatian       2              Croatia
# 29878            20210601           Croatian       1              Croatia
# 29879            20210401          Bulgarian       1             Bulgaria
# 29880            20210601          Bulgarian       2             Bulgaria
# 29881            20210301           Albanian       1              Albania
#
#           ComponentName QueueCategory QueueCategory1 QueueCategory2  \
# ...
